# %%
# Install necessary packages
# pandas , azure-storage-blob, dotenv
# !pip install pandas azure-storage-blob python-dotenv
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.2)
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.25.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: python-dotenv in c:\users\admin\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Using cached azure_core-1.34.0-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\admin\anaconda3\lib\site-packages (from azure-storage-blob) (43.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\admin\anaconda3\lib\site-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\admin\anaconda3\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.12.14)
# Using cached azure_storage_blob-12.25.1-py3-none-any.whl (406 kB)
# Using cached azure_core-1.34.0-py3-none-any.whl (207 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.34.0 azure-storage-blob-12.25.1 isodate-0.7.2

# %%
# Importing necessary libraries
import pandas as pd
from azure.storage.blob import BlobServiceClient
from dotenv import load_dotenv
import os

# %%
# Data Extraction

try:
    data = pd.read_json(r'MarketsData.json')
    print('Data extracted successfully')
except Exception as e:
    print(f'Error extracting data: {e}')
# Out:
# Data extracted successfully

# %%
data.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3       ripple    xrp       XRP
# 4  binancecoin    bnb       BNB
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...      107598.00
# 1  https://coin-images.coingecko.com/coins/images...        2521.01
# 2  https://coin-images.coingecko.com/coins/images...           1.00
# 3  https://coin-images.coingecko.com/coins/images...           2.30
# 4  https://coin-images.coingecko.com/coins/images...         667.39
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  2137849603370                1            2137849603370   28668694414
# 1   304290661820                2             304290661820   13450389192
# 2   152777148448                3             152777148448   45624245689
# 3   135192724252                4             230334194294    1725587726
# 4    97364572479                5              97364572479     760237143
#
#     high_24h  ...  total_supply    max_supply        ath  \
# 0  109071.00  ...  1.986980e+07  2.100000e+07  111814.00
# 1    2554.59  ...  1.207260e+08           NaN    4878.26
# 2       1.00  ...  1.527330e+11           NaN       1.32
# 3       2.35  ...  9.998611e+10  1.000000e+11       3.40
# 4     674.99  ...  1.458876e+08  2.000000e+08     788.84
#
#    ath_change_percentage                  ath_date        atl  \
# 0               -3.75094  2025-05-22T18:41:28.492Z  67.810000
# 1              -48.34656  2021-11-10T14:24:19.604Z   0.432979
# 2              -24.39731  2018-07-24T00:00:00.000Z   0.572521
# 3              -32.19464  2018-01-07T00:00:00.000Z   0.002686
# 4              -15.38177  2024-12-04T10:35:25.220Z   0.039818
#
#    atl_change_percentage                  atl_date  \
# 0           1.586106e+05  2013-07-06T00:00:00.000Z
# 1           5.818659e+05  2015-10-20T00:00:00.000Z
# 2           7.471772e+01  2015-03-02T00:00:00.000Z
# 3           8.568384e+04  2014-05-22T00:00:00.000Z
# 4           1.676304e+06  2017-10-19T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2025-05-25T20:37:23.382Z
# 1  {'times': 30.32373818665742, 'currency': 'btc'...  2025-05-25T20:37:23.056Z
# 2                                               None  2025-05-25T20:37:23.139Z
# 3                                               None  2025-05-25T20:37:22.786Z
# 4                                               None  2025-05-25T20:37:21.303Z
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                100 non-null    object
#  1   symbol                            100 non-null    object
#  2   name                              100 non-null    object
#  3   image                             100 non-null    object
#  4   current_price                     100 non-null    float64
#  5   market_cap                        100 non-null    int64
#  6   market_cap_rank                   100 non-null    int64
#  7   fully_diluted_valuation           100 non-null    int64
#  8   total_volume                      100 non-null    int64
#  9   high_24h                          100 non-null    float64
#  10  low_24h                           100 non-null    float64
#  11  price_change_24h                  100 non-null    float64
#  12  price_change_percentage_24h       100 non-null    float64
#  13  market_cap_change_24h             100 non-null    float64
#  14  market_cap_change_percentage_24h  100 non-null    float64
#  15  circulating_supply                100 non-null    float64
#  16  total_supply                      100 non-null    float64
#  17  max_supply                        51 non-null     float64
#  18  ath                               100 non-null    float64
#  19  ath_change_percentage             100 non-null    float64
#  20  ath_date                          100 non-null    object
#  21  atl                               100 non-null    float64
#  22  atl_change_percentage             100 non-null    float64
#  23  atl_date                          100 non-null    object
#  24  roi                               13 non-null     object
#  25  last_updated                      100 non-null    object
# dtypes: float64(14), int64(4), object(8)
# memory usage: 20.4+ KB

# %%
# Data cleaning and transformation
# Handling missing values ( filling missing numeric values with mean or median )
numeric_columns = data.select_dtypes(include=['float64', 'Int64']).columns
for col in numeric_columns:
    data.fillna({col: data[col].mean()}, inplace=True)

# %%
# Handling missing values ( filling missing object/string values with 'Unknown' )
string_columns = data.select_dtypes(include=['object']).columns
for col in string_columns:
    data.fillna({col: 'Unknown'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                100 non-null    object
#  1   symbol                            100 non-null    object
#  2   name                              100 non-null    object
#  3   image                             100 non-null    object
#  4   current_price                     100 non-null    float64
#  5   market_cap                        100 non-null    int64
#  6   market_cap_rank                   100 non-null    int64
#  7   fully_diluted_valuation           100 non-null    int64
#  8   total_volume                      100 non-null    int64
#  9   high_24h                          100 non-null    float64
#  10  low_24h                           100 non-null    float64
#  11  price_change_24h                  100 non-null    float64
#  12  price_change_percentage_24h       100 non-null    float64
#  13  market_cap_change_24h             100 non-null    float64
#  14  market_cap_change_percentage_24h  100 non-null    float64
#  15  circulating_supply                100 non-null    float64
#  16  total_supply                      100 non-null    float64
#  17  max_supply                        100 non-null    float64
#  18  ath                               100 non-null    float64
#  19  ath_change_percentage             100 non-null    float64
#  20  ath_date                          100 non-null    object
#  21  atl                               100 non-null    float64
#  22  atl_change_percentage             100 non-null    float64
#  23  atl_date                          100 non-null    object
#  24  roi                               100 non-null    object
#  25  last_updated                      100 non-null    object
# dtypes: float64(14), int64(4), object(8)
# memory usage: 20.4+ KB

# %%
data.columns
# Out:
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')

# %%
# creating a crypto_assets table
crypto_assets = data[['name', 'symbol', 'current_price', 'market_cap', 'total_volume', 'price_change_percentage_24h']].drop_duplicates().reset_index(drop=True)
crypto_assets.index.name = 'asset_id'
crypto_assets = crypto_assets.reset_index()

# %%
crypto_assets.head()
# Out:
#    asset_id      name symbol  current_price     market_cap  total_volume  \
# 0         0   Bitcoin    btc      107598.00  2137849603370   28668694414
# 1         1  Ethereum    eth        2521.01   304290661820   13450389192
# 2         2    Tether   usdt           1.00   152777148448   45624245689
# 3         3       XRP    xrp           2.30   135192724252    1725587726
# 4         4       BNB    bnb         667.39    97364572479     760237143
#
#    price_change_percentage_24h
# 0                     -1.35079
# 1                     -1.30773
# 2                      0.00841
# 3                     -1.94777
# 4                     -1.12717

# %%
# create crypto_market table
crypto_market = data[['market_cap_rank', 'high_24h', 'low_24h', 'price_change_24h', 'price_change_percentage_24h']].drop_duplicates().reset_index(drop=True)
crypto_market.index.name = 'market_id'
crypto_market = crypto_market.reset_index()

# %%
crypto_market.head()
# Out:
#    market_id  market_cap_rank   high_24h    low_24h  price_change_24h  \
# 0          0                1  109071.00  106802.00      -1473.319665
# 1          1                2    2554.59    2479.53        -33.404854
# 2          2                3       1.00       1.00          0.000084
# 3          3                4       2.35       2.28         -0.045759
# 4          4                5     674.99     657.95         -7.608362
#
#    price_change_percentage_24h
# 0                     -1.35079
# 1                     -1.30773
# 2                      0.00841
# 3                     -1.94777
# 4                     -1.12717

# %%
# create crypto_prices table
crypto_prices = data[['current_price', 'price_change_24h', 'price_change_percentage_24h']].drop_duplicates().reset_index(drop=True)
crypto_prices.index.name = 'price_id'
crypto_prices = crypto_prices.reset_index()

# %%
crypto_prices.head()
# Out:
#    price_id  current_price  price_change_24h  price_change_percentage_24h
# 0         0      107598.00      -1473.319665                     -1.35079
# 1         1        2521.01        -33.404854                     -1.30773
# 2         2           1.00          0.000084                      0.00841
# 3         3           2.30         -0.045759                     -1.94777
# 4         4         667.39         -7.608362                     -1.12717

# %%
# create crypto datetime table
crypto_datetime = data[['name', 'last_updated']].drop_duplicates().reset_index(drop=True)
crypto_datetime.index.name = 'datetime_id'
crypto_datetime = crypto_datetime.reset_index()

# %%
crypto_datetime.head()
# Out:
#    datetime_id      name              last_updated
# 0            0   Bitcoin  2025-05-25T20:37:23.382Z
# 1            1  Ethereum  2025-05-25T20:37:23.056Z
# 2            2    Tether  2025-05-25T20:37:23.139Z
# 3            3       XRP  2025-05-25T20:37:22.786Z
# 4            4       BNB  2025-05-25T20:37:21.303Z

# %%
# transaction table
transaction = data.merge(crypto_assets, on=['name', 'symbol', 'current_price', 'market_cap', 'total_volume', 'price_change_percentage_24h'], how='left') \
                   .merge(crypto_market, on=['market_cap_rank', 'high_24h', 'low_24h', 'price_change_24h', 'price_change_percentage_24h'], how='left') \
                   .merge(crypto_prices, on=['current_price', 'price_change_24h', 'price_change_percentage_24h'], how='left') \
                   .merge(crypto_datetime, on=['name', 'last_updated'], how='left')

transaction.index.name = 'transaction_id'
transaction = transaction.reset_index() \
                         [[ 'transaction_id', 'asset_id', 'market_id', 'price_id', 'datetime_id', 
                           'name', 'symbol', 'current_price', 'market_cap', 'total_volume', 
                           'price_change_percentage_24h', 'market_cap_rank', 'high_24h', 
                           'low_24h', 'price_change_24h', 'last_updated']]

# %%
transaction.head()
# Out:
#    transaction_id  asset_id  market_id  price_id  datetime_id      name  \
# 0               0         0          0         0            0   Bitcoin
# 1               1         1          1         1            1  Ethereum
# 2               2         2          2         2            2    Tether
# 3               3         3          3         3            3       XRP
# 4               4         4          4         4            4       BNB
#
#   symbol  current_price     market_cap  total_volume  \
# 0    btc      107598.00  2137849603370   28668694414
# 1    eth        2521.01   304290661820   13450389192
# 2   usdt           1.00   152777148448   45624245689
# 3    xrp           2.30   135192724252    1725587726
# 4    bnb         667.39    97364572479     760237143
#
#    price_change_percentage_24h  market_cap_rank   high_24h    low_24h  \
# 0                     -1.35079                1  109071.00  106802.00
# 1                     -1.30773                2    2554.59    2479.53
# 2                      0.00841                3       1.00       1.00
# 3                     -1.94777                4       2.35       2.28
# 4                     -1.12717                5     674.99     657.95
#
#    price_change_24h              last_updated
# 0      -1473.319665  2025-05-25T20:37:23.382Z
# 1        -33.404854  2025-05-25T20:37:23.056Z
# 2          0.000084  2025-05-25T20:37:23.139Z
# 3         -0.045759  2025-05-25T20:37:22.786Z
# 4         -7.608362  2025-05-25T20:37:21.303Z

# %%
transaction['date'] = pd.to_datetime(transaction['last_updated'])

# %%
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   transaction_id               100 non-null    int64
#  1   asset_id                     100 non-null    int64
#  2   market_id                    100 non-null    int64
#  3   price_id                     100 non-null    int64
#  4   datetime_id                  100 non-null    int64
#  5   name                         100 non-null    object
#  6   symbol                       100 non-null    object
#  7   current_price                100 non-null    float64
#  8   market_cap                   100 non-null    int64
#  9   total_volume                 100 non-null    int64
#  10  price_change_percentage_24h  100 non-null    float64
#  11  market_cap_rank              100 non-null    int64
#  12  high_24h                     100 non-null    float64
#  13  low_24h                      100 non-null    float64
#  14  price_change_24h             100 non-null    float64
#  15  last_updated                 100 non-null    object
#  16  date                         100 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(5), int64(8), object(3)
# memory usage: 13.4+ KB

# %%
# Saving the data to CSV files
data.to_csv('cleaned_data.csv', index=False)
crypto_assets.to_csv('crypto_assets.csv', index=False)
crypto_market.to_csv('crypto_market.csv', index=False)
crypto_prices.to_csv('crypto_prices.csv', index=False)
crypto_datetime.to_csv('crypto_datetime.csv', index=False)
transaction.to_csv('transaction.csv', index=False)
